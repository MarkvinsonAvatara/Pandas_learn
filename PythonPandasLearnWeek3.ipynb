# %% [markdown]
# # Pandas week 3

# %% [markdown]
# # 9. Membagi Data Frame menjadi dua secara acak

# %%
#import modules
import pandas as pd
import numpy as np 

#check Version
print(pd.__version__)
print(np.__version__)

# %%
#Data Frame Prep
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1,25, size=(n_rows, n_cols)),
                 columns=cols)

df

# %% [markdown]
# # Membagi Data Frame menjadi dua secara acak berdasarkan proporsi tertentu

# %%
df.shape#menghitung jumlas baris dan kolom (kanan baris dan kiri kolom )

# %%
#membagi data Frame
proporsi= 0.8 #80% data pertama dan sisanya untuk data kedua
df_1 = df.sample(frac=proporsi)
#df.sample(): method yang mengambil baris secara acak sesuai nilai parameter fracnya
df_2 = df.drop(df_1.index)#--> isinya menghapus baris yang sudah ada di df_1 (sisa data dari df_1)

print(f'df_1shape: {df_1.shape}')
print(f'df_2shape: {df_2.shape}')

# %%
# isi df_1
df_1

# %%
#isi df_2
df_2

# %% [markdown]
# # 10. Mengganti nama kolom pada Data Frame berdasarkan pola

# %%
#import modules
import pandas as pd
import numpy as np 
import os

#check Version
print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %%
#Data Frame Prep
cf = pd.read_csv('C:/Users/Markvinson/Visualisasi data/Pandas/data/data/titanicfull.csv') #mengload dataset yang awalnya csv menjadi data Frame
#prep data kali menggunakan dataset titanic, jadi dapat langsung diakses 
cf.columns= ['Pclass', 'Survival Status', 'Full Name','Sex',' Age',
            'Sib SP', 'Parch', 'Ticket','Fare', 'Cabin', 'Embarked']

cf_backup=cf.copy(deep=True)
cf.head()
# Out:
#    Pclass  Survival Status                                        Full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# # Menggunakan lowercase untuk nama kolom dan mengganti spasi dengan _

# %%
cf.columns= cf.columns.str.replace(' ','_').str.lower() #merubah semua huruf pada kolom menjadi huruf kecil dan mengganti semua spasi dengan _
#str.replace('','_')-->
#str.lower()-->mengubah semua nama kolom menjadi huruf kecil 
#str.upper()-->mengubah semua nama kolom menjadi huruf besar
cf.head()
# Out:
#    _p_c_l_a_s_s_  _s_u_r_v_i_v_a_l___s_t_a_t_u_s_  \
# 0              1                                1
# 1              1                                1
# 2              1                                0
# 3              1                                0
# 4              1                                0
#
#                                _f_u_l_l___n_a_m_e_ _s_e_x_  _a_g_e_  \
# 0                    Allen, Miss. Elisabeth Walton  female    29.00
# 1                   Allison, Master. Hudson Trevor    male     0.92
# 2                     Allison, Miss. Helen Loraine  female     2.00
# 3             Allison, Mr. Hudson Joshua Creighton    male    30.00
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female    25.00
#
#    _s_i_b___s_p_  _p_a_r_c_h_ _t_i_c_k_e_t_  _f_a_r_e_ _c_a_b_i_n_  \
# 0              0            0         24160   211.3375          B5
# 1              1            2        113781   151.5500     C22 C26
# ...

# %% [markdown]
# # Memangkas kelebihan spasi pada nama kolom

# %%
cf=cf_backup.copy(deep=True)
cf.columns = cf.columns.str.lower().str.strip().str.replace(' ','_')
#str.strip()--> memotong kelebihan spasi di sisi kanan dan di sisi kiri
cf.head()
# Out:
#    pclass  survival_status                                        full_name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex    age  sib_sp  parch  ticket      fare    cabin embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# # 11. Seleksi kolom dan baris pada Data Frame menggunakan loc

# %%
#import modules
import pandas as pd
import numpy as np 

#check Version
print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %%
#Data Frame Prep
n_rows=10
n_cols=5
cols = tuple('ABCDE')

sf= pd.DataFrame(np.random.randint(1,20,size=(n_rows,n_cols)),
                columns=cols)
sf
# Out:
#     A   B   C   D   E
# 0  10  13  14  13   7
# 1  19   5   1  12  18
# 2   5  18   3  15   3
# 3  16   5  19  16   9
# 4  12  14   6   2  19
# 5   8  11  10  14   1
# 6  18   8  19  12  12
# 7   2   5   1  14  18
# 8   5  19   1   1   8
# 9   1   3  18   8  12

# %% [markdown]
# # Seleksi kolom dan baris dengan menggunakan loc

# %%
sf.loc[[0,1,5],['A','D']]
#Bagian pertama untuk baris bagian kedua untuk kolom
# Out:
#     A   D
# 0  10  13
# 1  19  12
# 5   8  14

# %% [markdown]
# # Seleksi baris dengan kondisi

# %%
sf.loc[sf['B']>10,['B','D','E']]
#bagian pertama memiliki kondisi dimana nilai kolom B lebih besar dari 10
# Out:
#     B   D   E
# 0  13  13   7
# 2  18  15   3
# 4  14   2  19
# 5  11  14   1
# 8  19   1   8

# %% [markdown]
# # Slicing data frame dengan loc

# %%
sf.loc[0:4,'B':'C']
#0:4 berarti dari baris 0 sampai baris 4 
#B:C berarti dari kolom B sampai kolom C
# Out:
#     B   C
# 0  13  14
# 1   5   1
# 2  18   3
# 3   5  19
# 4  14   6

# %% [markdown]
# # 12. Membentuk kolom bertipe datetime dari beberapa kolom lain

# %%
#import modules
import pandas as pd
import numpy as np 

#check Version
print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %%
datas= {'day':[1,2,10,25,12],
       'month':[1,2,4,5,6],
       'year':[2000,2001,2010,2015,2020]}

tf= pd.DataFrame(datas)
tf
# Out:
#    day  month  year
# 0    1      1  2000
# 1    2      2  2001
# 2   10      4  2010
# 3   25      5  2015
# 4   12      6  2020

# %% [markdown]
# # Membentuk kolom bertipe datetime

# %%
tf['Penanggalan'] = pd.to_datetime(tf[['day', 'month','year']])
tf
# Out:
#    day  month  year Penanggalan
# 0    1      1  2000  2000-01-01
# 1    2      2  2001  2001-02-02
# 2   10      4  2010  2010-04-10
# 3   25      5  2015  2015-05-25
# 4   12      6  2020  2020-06-12

# %%
tf.dtypes
# Out:
# day                     int64
# month                   int64
# year                    int64
# Penanggalan    datetime64[ns]
# dtype: object

# %% [markdown]
# source: https://www.youtube.com/playlist?list=PL2O3HdJI4voGdD_9xhVCTBoDTDNHpajm5
