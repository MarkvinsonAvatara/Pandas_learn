# %% [markdown]
# # Pandas week 7

# %% [markdown]
# # 25. Pengaturan tampilan pada Python Pandas

# %%
#import modules
import pandas as pd
import numpy as np 

#check Version
print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %%
#Data Frame Prep
pf = pd.read_csv('datasets/titanicfull.csv')
pf.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# # Pengaturan Tampilan

# %% [markdown]
# untuk mengatur tampilan kita hanya perlu menggunakan:
# - fungsi pd.set_option('pengaturan tampilan apa yang ingin mau kita lakukan', ukuran yang ingin kita tentukan)

# %%
#Contoh
pd.set_option('display.max_rows', 7) # Menentunkan jumlah maximal baris 
pd.set_option('display.max_columns', 8) #Menentunkan jumlah maximal kolom
pd.set_option('display.max_colwidth', 25) #Menentukan jumlah maximal karkter untuk setiap kolom

pf
#note jika ada yang lebih dari nilai maximal yang ditetapkan akan diberi tanda "...""
# Out:
#       pclass  survived                      name     sex  ...  ticket  \
# 0          1         1  Allen, Miss. Elisabet...  female  ...   24160
# 1          1         1  Allison, Master. Huds...    male  ...  113781
# 2          1         0  Allison, Miss. Helen ...  female  ...  113781
# ...      ...       ...                       ...     ...  ...     ...
# 1306       3         0  Zakarian, Mr. Mapried...    male  ...    2656
# 1307       3         0       Zakarian, Mr. Ortin    male  ...    2670
# 1308       3         0        Zimmerman, Mr. Leo    male  ...  315082
#
#           fare    cabin embarked
# 0     211.3375       B5        S
# 1     151.5500  C22 C26        S
# 2     151.5500  C22 C26        S
# ...        ...      ...      ...
# 1306    7.2250      NaN        C
# 1307    7.2250      NaN        C
# 1308    7.8750      NaN        S
#
# [1309 rows x 11 columns]

# %%
#contoh 2
pd.reset_option('^display.', silent=True) #mereset ulang display option ke kondisi default
pf
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked
# ...

# %% [markdown]
# pd.describe_option(); #melihat banyak pengaturan yang bisa kita lakukan pada python pandas

# %% [markdown]
# # 26. Membuat Data Frame dari hasil seleksi Spreadsheet

# %%
#import modules
import pandas as pd
import numpy as np 

#check Version
print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %% [markdown]
# # Membuat Data Frame dari hasil seleksi Spreadsheet

# %% [markdown]
# Untuk membuat Data Frame dari hasil seleksi Spreadsheet kita hanya perlu mengcopy bagian yang ingin masukan ke Data Frame yang ingin kita buit kemudian memanggil fungsi pd.read_clipboard()

# %%
#Contoh 1
pd.read_clipboard()
# Out:
#    No_series   Name
# 0      22345   Alex
# 1      22346  Aster
# 2      22347   Jack
# 3      22348  Chazz

# %%
#contoh 2
sf=pd.read_clipboard()
sf
# Out:
#    No_series   Name
# 0      22345   Alex
# 1      22346  Aster
# 2      22347   Jack
# 3      22348  Chazz
